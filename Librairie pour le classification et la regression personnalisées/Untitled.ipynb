# %%
from ML import config, experimentation
import pandas as pd
import numpy as np
from sklearn import datasets

# %% [markdown]
# # Pour la classification

# %%
iris = datasets.load_iris()
columns = iris["feature_names"]
columns.append("iris")
data = pd.DataFrame(data = np.concatenate((iris["data"], np.reshape(iris["target"], (-1, 1))),axis=1 ) , columns = columns)
data.to_excel("iris_dataset.xlsx")

# %%
def load_dataset(filepath: str, **kwargs):
    
    df = pd.read_excel(io = filepath, sheet_name = 'Sheet1', keep_default_na=False, index_col = 0)    
    
    return df

# %%
target_col = 'iris'
filepath = './iris_dataset.xlsx'
task = 'classif'
config_dir  = './experiment'
metrics = ['Accuracy', 'balancedAcc','F1']
cross_validation = ['stratified_kfold']

models = ["random_forest"]
experiment = '%s_model_selection'%target_col
conf = config.Config(target_col=target_col, filepath=filepath, task=task,experiment=experiment, config_dir=config_dir, cross_validation=cross_validation, metrics = metrics, models = models)
result_filepath =  experimentation.run_experiment(conf, load_dataset)
# Out:
# ------------random_forest--------------------------------
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END  Acc. label = 0: (test=nan) Acc. label = 1: (test=nan) Acc. label = 2: (test=nan) Accuracy: (test=nan) F1: (test=nan) balancedAcc: (test=nan) total time=   0.0s
# [CV 2/5] END  Acc. label = 0: (test=nan) Acc. label = 1: (test=nan) Acc. label = 2: (test=nan) Accuracy: (test=nan) F1: (test=nan) balancedAcc: (test=nan) total time=   0.0s
# [CV 3/5] END  Acc. label = 0: (test=nan) Acc. label = 1: (test=nan) Acc. label = 2: (test=nan) Accuracy: (test=nan) F1: (test=nan) balancedAcc: (test=nan) total time=   0.0s
# [CV 4/5] END  Acc. label = 0: (test=nan) Acc. label = 1: (test=nan) Acc. label = 2: (test=nan) Accuracy: (test=nan) F1: (test=nan) balancedAcc: (test=nan) total time=   0.0s
# ...

# %%
resultat = experimentation.display_result(result_filepath)
drop = [col for col in list(resultat) if 'rank' in col or 'fit' in col or 'time' in col or 'split' in col]
resultat = resultat.drop(drop, axis = 1)
top = resultat.sort_values( 'mean_test_balancedAcc',ascending = False)[:10]
top
# Out:
#   data_normalizer sampler          model                cv  cv_args  \
# 0            None    None  random_forest  stratified_kfold  default
#
#   model_args feat. selection params  mean_test_Accuracy  std_test_Accuracy  \
# 0    default            None     {}                 NaN                NaN
#
#    mean_test_balancedAcc  std_test_balancedAcc  mean_test_F1  std_test_F1  \
# 0                    NaN                   NaN           NaN          NaN
#
#    mean_test_Acc. label = 0  std_test_Acc. label = 0  \
# 0                       NaN                      NaN
#
#    mean_test_Acc. label = 1  std_test_Acc. label = 1  \
# 0                       NaN                      NaN
#
#    mean_test_Acc. label = 2  std_test_Acc. label = 2
# 0                       NaN                      NaN

# %% [markdown]
# # Pour la regression

# %%
boston = datasets.load_boston()
columns = boston["feature_names"].tolist()
columns.append("target")
data = pd.DataFrame(data = np.concatenate((boston["data"], np.reshape(boston["target"], (-1, 1))),axis=1 ) , columns = columns)
data.to_excel("boston_dataset.xlsx")

# %%
target_col = 'target'
filepath = './boston_dataset.xlsx'
task = 'reg'
config_dir  = './experiment'
metrics = ['MSE', 'R2']
cross_validation = ['stratified_kfold']

models = ["random_forest"]
experiment = '%s_model_selection'%target_col
conf = config.Config(target_col=target_col, filepath=filepath, task=task,experiment=experiment, config_dir=config_dir, cross_validation=cross_validation, metrics = metrics, models = models)
result_filepath =  experimentation.run_experiment(conf, load_dataset)
# Out:
# ------------random_forest--------------------------------
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-a1297d437a06> in <module>
#       9 experiment = '%s_model_selection'%target_col
#      10 conf = config.Config(target_col=target_col, filepath=filepath, task=task,experiment=experiment, config_dir=config_dir, cross_validation=cross_validation, metrics = metrics, models = models)
# ---> 11 result_filepath =  experimentation.run_experiment(conf, load_dataset)
#
# d:\leapconseil work\anaconda workspace\cnesst juridique\données\cout du dossier\codebase\ML\experimentation.py in run_experiment(cfg, read, output_dir, **kwargs)
#      89             clf = GridSearchCV(estimator=estimator, param_grid=param_grid, scoring=scorer,
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
tt = RandomForestRegressor().fit(boston["data"],boston["target"])

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# ...
